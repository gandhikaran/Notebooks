# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#x=np.array([1,2,3,4,5])
#y=np.array([2,9,88,4,1])
plt.figure(figsize=(5,3))

x = np.arange(0,5,0.1)
y = np.sin(x)
z = np.cos(x)
plt.title('tghgfytvuygu')

plt.plot(x[:11],y[:11], 'b',label='AA')
plt.plot(x[10:],y[10:], 'b--')
plt.plot(x,z, 'r',label='AA')
#plt.plot(x,z, 'r',label='AA')
plt.axvline(x=1,color='r',alpha=0.3)
plt.legend()
#print(x[np.sin(x)==np.cos(x)])
plt.savefig('Mera pehla pehla Graph hai ye woooooo.png',dpi=300)


plt.show()

# %%
plt.figure(figsize=(5,3))
labels=['A','B','C','D','E','F']
values=[1,4,2,3,6,1]
values2=[3,6,1]
bars=plt.bar(labels,values)
pattern=['/','o','*','/','o','*']
i=0
for bar in bars:
    bar.set_hatch(pattern[i])
    i=i+1
#plt.bar(labels,values2,alpha=0.3)
plt.show()

# %%
a=input("Enter:")
print(a)
