# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'][9])
# Out:
# Squirtle

# %%
df.iloc[20]
# Out:
# #                 16
# Name          Pidgey
# Type 1        Normal
# Type 2        Flying
# HP                40
# Attack            45
# Defense           40
# Sp. Atk           35
# Sp. Def           35
# Speed             56
# Generation         1
# Legendary      False
# Name: 20, dtype: object

# %%
df.iloc[20,2:5]
# Out:
# Type 1    Normal
# Type 2    Flying
# HP            40
# Name: 20, dtype: object

# %%
df.iloc[20,1]
# Out:
# 'Pidgey'

# %%
df.sort_values(['Type 1','HP','Legendary'],ascending=False)[0:30]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 351  321                Wailord  Water       NaN  170      90       45
# 655  594              Alomomola  Water       NaN  165      75       80
# 142  131                 Lapras  Water       Ice  130      85       80
# 145  134               Vaporeon  Water       NaN  130      65       60
# 350  320                Wailmer  Water       NaN  130      70       35
# 185  171                Lanturn  Water  Electric  125      58       58
# 470  423              Gastrodon  Water    Ground  111      83       68
# 372  340               Whiscash  Water    Ground  110      78       73
# 597  537             Seismitoad  Water    Ground  105      95       75
# 264  245                Suicune  Water       NaN  100      75      115
# 421  382                 Kyogre  Water       NaN  100     100       90
# 422  382    KyogrePrimal Kyogre  Water       NaN  100     150       90
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total']=df.iloc[:,4:10].sum(axis=1)
import numpy as np
a=list(df.columns)
df = df[a[0:4] + a[7:13] +a[4:7]]
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  Sp. Atk  Sp. Def  Speed  \
# 0      1              Bulbasaur    Grass  Poison       65       65     45
# 1      2                Ivysaur    Grass  Poison       80       80     60
# 2      3               Venusaur    Grass  Poison      100      100     80
# 3      3  VenusaurMega Venusaur    Grass  Poison      122      120     80
# 4      4             Charmander     Fire     NaN       60       50     65
# ..   ...                    ...      ...     ...      ...      ...    ...
# 795  719                Diancie     Rock   Fairy      100      150     50
# 796  719    DiancieMega Diancie     Rock   Fairy      160      110    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost      150      130     70
# 798  720     HoopaHoopa Unbound  Psychic    Dark      170      130     80
# 799  721              Volcanion     Fire   Water      130       90     70
#
#      Generation  Legendary  HP  Attack  Defense
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  Sp. Atk  Sp. Def  Speed  \
# 0      1              Bulbasaur    Grass  Poison       65       65     45
# 1      2                Ivysaur    Grass  Poison       80       80     60
# 2      3               Venusaur    Grass  Poison      100      100     80
# 3      3  VenusaurMega Venusaur    Grass  Poison      122      120     80
# 4      4             Charmander     Fire     NaN       60       50     65
# ..   ...                    ...      ...     ...      ...      ...    ...
# 795  719                Diancie     Rock   Fairy      100      150     50
# 796  719    DiancieMega Diancie     Rock   Fairy      160      110    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost      150      130     70
# 798  720     HoopaHoopa Unbound  Psychic    Dark      170      130     80
# 799  721              Volcanion     Fire   Water      130       90     70
#
#      Generation  Legendary  Total  HP  Attack  Defense
# ...

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total']=df['HP'][1:5]+df['Attack'][4:10]+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    NaN
# ...

# %%
df=df[['Total','HP']]

# %%
df
# Out:
#      Total  HP
# 0      NaN  45
# 1      NaN  60
# 2      NaN  80
# 3      NaN  80
# 4    309.0  39
# ..     ...  ..
# 795    NaN  50
# 796    NaN  50
# 797    NaN  80
# 798    NaN  80
# 799    NaN  80
#
# [800 rows x 2 columns]

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.to_csv('modified.csv')

# %%
df.loc[df['Name']=='Charizard']
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 6  6  Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary  Total
# 6           1      False    534

# %%
df.loc[(df['Type 1']=='Flying')|(df['Type 2']=='Flying')]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# ..   ...                        ...       ...     ...  ...     ...      ...
# 734  666                   Vivillon       Bug  Flying   80      52       50
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 790  714                     Noibat    Flying  Dragon   40      30       35
# 791  715                    Noivern    Flying  Dragon   85      70       80
# 793  717                    Yveltal      Dark  Flying  126     131       95
#
# ...

# %%
df.groupby(['Type 1','Type 2']).count()['#']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: #, Length: 136, dtype: int64

# %%
new_df=pd.DataFrame(columns=df.columns)

for df in pd.read_csv('pokemon_data.csv', chunksize=5):
    results= df['Type 1']
    
    new_df=pd.concat([new_df,df],sort=False)
    print('____________________________________________________________')
    print(new_df)
# Out:
# ____________________________________________________________
#    #                   Name Type 1  Type 2  HP Attack Defense Sp. Atk Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45     49      49      65      65
# 1  2                Ivysaur  Grass  Poison  60     62      63      80      80
# 2  3               Venusaur  Grass  Poison  80     82      83     100     100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80    100     123     122     120
# 4  4             Charmander   Fire     NaN  39     52      43      60      50
#
#   Speed Generation Legendary
# 0    45          1     False
# 1    60          1     False
# 2    80          1     False
# 3    80          1     False
# 4    65          1     False
# ____________________________________________________________
#    #                       Name Type 1  Type 2  HP Attack Defense Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45     49      49      65
# ...
